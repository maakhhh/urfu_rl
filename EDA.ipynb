# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

attack_data = pd.read_csv("CTU13_Attack_Traffic.csv")
normal_data = pd.read_csv("CTU13_Normal_Traffic.csv")

# %%
attack_data.describe()
# Out:
#          Unnamed: 0  Flow Duration  Tot Fwd Pkts  Tot Bwd Pkts  \
# count  38898.000000   3.889800e+04  38898.000000  38898.000000
# mean   19449.318808   9.156633e+06     13.609646      9.185331
# std    11229.979199   2.112623e+07    311.173197     95.260839
# min        0.000000   1.000000e+00      0.000000      1.000000
# 25%     9724.250000   2.950000e+02      1.000000      1.000000
# 50%    19448.500000   3.974740e+05      1.000000      1.000000
# 75%    29174.750000   9.012726e+06      5.000000      3.000000
# max    38901.000000   1.200000e+08  15123.000000   9555.000000
#
#        TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  Fwd Pkt Len Min  \
# count     3.889800e+04     3.889800e+04     38898.000000     38898.000000
# mean      6.171164e+03     8.097564e+03        63.507610        13.725050
# std       3.394345e+05     1.326952e+05       202.203633        48.467214
# min       0.000000e+00     0.000000e+00         0.000000         0.000000
# ...

# %%
normal_data.describe()
# Out:
#          Unnamed: 0  Flow Duration  Tot Fwd Pkts  Tot Bwd Pkts  \
# count  53314.000000   5.331400e+04  53314.000000  53314.000000
# mean   26658.075571   1.183955e+07      8.998049     15.738624
# std    15391.137943   3.065518e+07    191.328376    233.664390
# min        0.000000   1.300000e+01      0.000000      1.000000
# 25%    13329.250000   2.432650e+04      0.000000      2.000000
# 50%    26658.500000   4.228100e+04      0.000000      2.000000
# 75%    39986.750000   3.724082e+05      2.000000      2.000000
# max    53315.000000   1.199996e+08  13707.000000  21933.000000
#
#        TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  Fwd Pkt Len Min  \
# count     5.331400e+04     5.331400e+04     53314.000000     53314.000000
# mean      5.184460e+03     1.175429e+04        88.015512         1.682954
# std       2.391167e+05     2.514014e+05       243.945402        12.427593
# min       0.000000e+00     0.000000e+00         0.000000         0.000000
# ...

# %%
attack_data.isnull().sum()
# Out:
# Unnamed: 0           0
# Flow Duration        0
# Tot Fwd Pkts         0
# Tot Bwd Pkts         0
# TotLen Fwd Pkts      0
# TotLen Bwd Pkts      0
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Flow IAT Mean        0
# Flow IAT Std         0
# Flow IAT Max         0
# Flow IAT Min         0
# Fwd IAT Tot          0
# Fwd IAT Mean         0
# Fwd IAT Std          0
# Fwd IAT Max          0
# Fwd IAT Min          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Bwd PSH Flags        0
# Fwd Header Len       0
# Bwd Header Len       0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# ...

# %%
normal_data.isnull().sum()
# Out:
# Unnamed: 0           0
# Flow Duration        0
# Tot Fwd Pkts         0
# Tot Bwd Pkts         0
# TotLen Fwd Pkts      0
# TotLen Bwd Pkts      0
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Flow IAT Mean        0
# Flow IAT Std         0
# Flow IAT Max         0
# Flow IAT Min         0
# Fwd IAT Tot          0
# Fwd IAT Mean         0
# Fwd IAT Std          0
# Fwd IAT Max          0
# Fwd IAT Min          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Bwd PSH Flags        0
# Fwd Header Len       0
# Bwd Header Len       0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# ...

# %% [markdown]
# # Построение гистограмм для сравнения атакующего и нормального трафика.

# %%
sns.histplot(x="Flow Duration", data = attack_data, color="#FF0000")
sns.histplot(x="Flow Duration", data = normal_data, color="#008000")
plt.show()

# %%
sns.histplot(x="Fwd Pkt Len Max", data = attack_data, color="#FF0000")
sns.histplot(x="Fwd Pkt Len Max", data = normal_data, color="#008000")
plt.xlim([0, 1000])
plt.ylim([0, 2500])
plt.show()

# %%
sns.histplot(x="Fwd Pkt Len Min", data = attack_data, color="#FF0000")
sns.histplot(x="Fwd Pkt Len Min", data = normal_data, color="#008000")
# plt.xlim([0, 1000])
# plt.ylim([0, 2500])
plt.show()

# %%
sns.histplot(x="Fwd Pkt Len Mean", data = attack_data, color="#FF0000")
sns.histplot(x="Fwd Pkt Len Mean", data = normal_data, color="#008000")
plt.xlim([0, 1000])
plt.ylim([0, 2500])
plt.show()

# %%
sns.histplot(x="Fwd Pkt Len Std", data = attack_data, color="#FF0000")
sns.histplot(x="Fwd Pkt Len Std", data = normal_data, color="#008000")
plt.xlim([0, 1000])
plt.ylim([0, 2500])
plt.show()

# %%
sns.histplot(x="Bwd Pkt Len Max", data = attack_data, color="#FF0000")
sns.histplot(x="Bwd Pkt Len Max", data = normal_data, color="#008000")
plt.xlim([0, 1000])
plt.ylim([0, 2500])
plt.show()

# %%
sns.histplot(x="Bwd Pkt Len Min", data = attack_data, color="#FF0000")
sns.histplot(x="Bwd Pkt Len Min", data = normal_data, color="#008000")
plt.xlim([0, 1000])
plt.ylim([0, 2500])
plt.show()

# %%
sns.histplot(x="Bwd Pkt Len Mean", data = attack_data, color="#FF0000")
sns.histplot(x="Bwd Pkt Len Mean", data = normal_data, color="#008000")
plt.xlim([0, 1000])
plt.ylim([0, 2500])
plt.show()

# %%
sns.histplot(x="Bwd Pkt Len Std", data = attack_data, color="#FF0000")
sns.histplot(x="Bwd Pkt Len Std", data = normal_data, color="#008000")
plt.xlim([0, 1000])
plt.ylim([0, 2500])
plt.show()

# %%
sns.histplot(x="Flow IAT Mean", data = attack_data, color="#FF0000")
sns.histplot(x="Flow IAT Mean", data = normal_data, color="#008000")
# plt.xlim([0, 0.3])
# plt.ylim([0, 8000])
plt.show()

# %%
sns.histplot(x="Fwd IAT Std", data = attack_data, color="#FF0000")
sns.histplot(x="Fwd IAT Std", data = normal_data, color="#008000")
# plt.xlim([0, 0.3])
# plt.ylim([0, 8000])
plt.show()

# %%
sns.histplot(x="Bwd IAT Tot", data = attack_data, color="#FF0000")
sns.histplot(x="Bwd IAT Tot", data = normal_data, color="#008000")
# plt.xlim([0, 0.2])
# plt.ylim([0, 1000])
plt.show()

# %%
sns.histplot(x="Bwd IAT Mean", data = attack_data, color="#FF0000")
sns.histplot(x="Bwd IAT Mean", data = normal_data, color="#008000")
plt.xlim([0, 0.1])
plt.ylim([0, 500])
plt.show()

# %%
sns.histplot(x="FIN Flag Cnt", data = attack_data, color="#FF0000")
sns.histplot(x="FIN Flag Cnt", data = normal_data, color="#008000")
# plt.xlim([0, 0.2])
# plt.ylim([0, 1000])
plt.show()

# %%
sns.histplot(x="SYN Flag Cnt", data = attack_data, color="#FF0000")
sns.histplot(x="SYN Flag Cnt", data = normal_data, color="#008000")
# plt.xlim([0, 0.2])
# plt.ylim([0, 1000])
plt.show()

# %%
sns.histplot(x="RST Flag Cnt", data = attack_data, color="#FF0000")
sns.histplot(x="RST Flag Cnt", data = normal_data, color="#008000")
# plt.xlim([0, 0.2])
# plt.ylim([0, 1000])
plt.show()

# %%
sns.histplot(x="ACK Flag Cnt", data = attack_data, color="#FF0000")
sns.histplot(x="ACK Flag Cnt", data = normal_data, color="#008000")
# plt.xlim([0, 0.2])
# plt.ylim([0, 1000])
plt.show()

# %%
sns.histplot(x="Down/Up Ratio", data = attack_data, color="#FF0000")
sns.histplot(x="Down/Up Ratio", data = normal_data, color="#008000")
# plt.xlim([0, 0.2])
# plt.ylim([0, 1000])
plt.show()

# %%
sns.histplot(x="Idle Std", data = attack_data, color="#FF0000")
sns.histplot(x="Idle Std", data = normal_data, color="#008000")
# plt.xlim([0, 0.2])
# plt.ylim([0, 1000])
plt.show()

# %%
sns.histplot(x="Active Std", data = attack_data, color="#FF0000")
sns.histplot(x="Active Std", data = normal_data, color="#008000")
# plt.xlim([0, 0.2])
# plt.ylim([0, 1000])
plt.show()

# %%
sns.histplot(x="Init Bwd Win Byts", data = attack_data, color="#FF0000")
sns.histplot(x="Init Bwd Win Byts", data = normal_data, color="#008000")
# plt.xlim([0, 0.2])
# plt.ylim([0, 1000])
plt.show()

# %% [markdown]
# Вывод: можно удалить фичи Fwd Pkt Len Mean, Bwd Pkt Len Max, Bwd Pkt Len Min, Flow IAT Std, Flow IAT Max, Flow IAT Min, Fwd IAT Tot, Fwd IAT Max, Fwd IAT Min, Bwd IAT Tot, Bwd IAT Mean, Bwd PSH Flags, Bwd Pkts/s, Pkt Len Mean, Pkt Len Std, Pkt Len Var, FIN Flag Cnt, RST Flag Cnt, ACK Flag Cnt, Down/Up Ratio, Pkt Size Avg, Idle Std, Idle Min
# так как атакующий и обычный трафик в них совпадает и не будет полезен для обучения.

# %% [markdown]
# # Корреляция данных

# %%
corr = attack_data['Idle Max'].corr(attack_data["Idle Min"])
print(corr)
# Out:
# 0.9077125977654583

# %%
corr = attack_data['Fwd Pkt Len Mean'].corr(attack_data["Bwd Pkt Len Mean"])
print(corr)
# Out:
# 0.18496760722259187

# %%
corr = attack_data['Bwd Pkt Len Max'].corr(attack_data["Fwd Pkt Len Max"])
print(corr)
# Out:
# 0.4585957419436209

# %%
corr = attack_data['Flow IAT Min'].corr(attack_data["Fwd IAT Tot"])
print(corr)
# Out:
# 0.17640664023618646

# %%
corr = attack_data['Bwd Pkts/s'].corr(attack_data["Fwd Pkts/s"])
print(corr)
# Out:
# 0.9651508422285822

# %%
corr = attack_data['Pkt Len Max'].corr(attack_data["Pkt Len Mean"])
print(corr)
# Out:
# 0.6704798523229594

# %%
corr = attack_data['Pkt Len Max'].corr(attack_data["Pkt Len Std"])
print(corr)
# Out:
# 0.9366655726276997

# %%
corr = attack_data['Pkt Len Max'].corr(attack_data["Pkt Len Var"])
print(corr)
# Out:
# 0.911848595586803

# %% [markdown]
# Вывод: можно удалить фичи Fwd Pkt Len Mean, Flow IAT Min, Fwd IAT Tot,  Bwd Pkts/s, Pkt Len Mean, Pkt Len Std, Pkt Len Var, Idle Min
